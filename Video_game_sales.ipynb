# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/font_manager.py:229: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
# %matplotlib inline

# %%
data_all = pd.read_csv("vgsales-12-4-2019.csv")

# %%
data_all.head()
# Out:
#    Rank                           Name                      basename  \
# 0     1                     Wii Sports                    wii-sports
# 1     2              Super Mario Bros.              super-mario-bros
# 2     3                 Mario Kart Wii                mario-kart-wii
# 3     4  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds
# 4     5              Wii Sports Resort             wii-sports-resort
#
#       Genre ESRB_Rating Platform         Publisher         Developer  \
# 0    Sports           E      Wii          Nintendo      Nintendo EAD
# 1  Platform         NaN      NES          Nintendo      Nintendo EAD
# 2    Racing           E      Wii          Nintendo      Nintendo EAD
# 3   Shooter         NaN       PC  PUBG Corporation  PUBG Corporation
# 4    Sports           E      Wii          Nintendo      Nintendo EAD
#
#    VGChartz_Score  Critic_Score  \
# 0             NaN           7.7
# 1             NaN          10.0
# ...

# %%
data_all.describe()
# Out:
#                Rank  VGChartz_Score  Critic_Score  User_Score  Total_Shipped  \
# count  55792.000000             0.0   6536.000000  335.000000    1827.000000
# mean   27896.500000             NaN      7.213709    8.253433       1.887258
# std    16105.907446             NaN      1.454079    1.401489       4.195693
# min        1.000000             NaN      1.000000    2.000000       0.030000
# 25%    13948.750000             NaN      6.400000    7.800000       0.200000
# 50%    27896.500000             NaN      7.500000    8.500000       0.590000
# 75%    41844.250000             NaN      8.300000    9.100000       1.800000
# max    55792.000000             NaN     10.000000   10.000000      82.860000
#
#        Global_Sales      NA_Sales     PAL_Sales     JP_Sales   Other_Sales  \
# count  19415.000000  12964.000000  13189.000000  7043.000000  15522.000000
# mean       0.365503      0.275541      0.155263     0.110402      0.044719
# ...

# %%
data_all.columns
# Out:
# Index(['Rank', 'Name', 'basename', 'Genre', 'ESRB_Rating', 'Platform',
#        'Publisher', 'Developer', 'VGChartz_Score', 'Critic_Score',
#        'User_Score', 'Total_Shipped', 'Global_Sales', 'NA_Sales', 'PAL_Sales',
#        'JP_Sales', 'Other_Sales', 'Year', 'Last_Update', 'url', 'status',
#        'Vgchartzscore', 'img_url'],
#       dtype='object')

# %%
data_all[['VGChartz_Score','Vgchartzscore']].describe()
# Out:
#        VGChartz_Score  Vgchartzscore
# count             0.0     799.000000
# mean              NaN       7.425907
# std               NaN       1.384226
# min               NaN       2.600000
# 25%               NaN       6.800000
# 50%               NaN       7.800000
# 75%               NaN       8.500000
# max               NaN       9.600000

# %% [markdown]
# ##### VGChartz_Score seems to be repetitive and needs to be removed along with a few other variables that do not seem to be useful.

# %%
data = data_all.drop(['Rank','Last_Update','url','status','img_url','VGChartz_Score'], axis=1)

# %%
data.head()
# Out:
#                             Name                      basename     Genre  \
# 0                     Wii Sports                    wii-sports    Sports
# 1              Super Mario Bros.              super-mario-bros  Platform
# 2                 Mario Kart Wii                mario-kart-wii    Racing
# 3  PlayerUnknown's Battlegrounds  playerunknowns-battlegrounds   Shooter
# 4              Wii Sports Resort             wii-sports-resort    Sports
#
#   ESRB_Rating Platform         Publisher         Developer  Critic_Score  \
# 0           E      Wii          Nintendo      Nintendo EAD           7.7
# 1         NaN      NES          Nintendo      Nintendo EAD          10.0
# 2           E      Wii          Nintendo      Nintendo EAD           8.2
# 3         NaN       PC  PUBG Corporation  PUBG Corporation           NaN
# 4           E      Wii          Nintendo      Nintendo EAD           8.0
#
#    User_Score  Total_Shipped  Global_Sales  NA_Sales  PAL_Sales  JP_Sales  \
# ...

# %%
data.shape
# Out:
# (55792, 17)

# %%
data.describe(include='all')
# Out:
#                       Name basename  Genre ESRB_Rating Platform Publisher  \
# count                55792    55792  55792       23623    55792     55792
# unique               37102    36672     20           8       74      3069
# top     Plants vs. Zombies     fate   Misc           E       PC   Unknown
# freq                    20       23   9476       10811    10978      4891
# mean                   NaN      NaN    NaN         NaN      NaN       NaN
# std                    NaN      NaN    NaN         NaN      NaN       NaN
# min                    NaN      NaN    NaN         NaN      NaN       NaN
# 25%                    NaN      NaN    NaN         NaN      NaN       NaN
# 50%                    NaN      NaN    NaN         NaN      NaN       NaN
# 75%                    NaN      NaN    NaN         NaN      NaN       NaN
# max                    NaN      NaN    NaN         NaN      NaN       NaN
#
#        Developer  Critic_Score  User_Score  Total_Shipped  Global_Sales  \
# ...

# %% [markdown]
# ### Top sellers based on publisher company

# %%
total_sale_company=data.groupby('Publisher').sum()

# %%
top_companies = total_sale_company.sort_values (by=['Global_Sales'], ascending=False)

# %%
top_companies[:15].Global_Sales.plot(kind='bar', title="Top 15 video game publishers based on global sales")

# %% [markdown]
# ### Top sellers based on genre

# %%
total_sale_genre=data.groupby('Genre').sum()

# %%
top_genre = total_sale_genre.sort_values (by=['Global_Sales'], ascending=False)

# %%
top_genre[:15].Global_Sales.plot(kind='bar', title="Top 15 video game genre based on global sales")

# %% [markdown]
# ### Top sellers based on platform

# %%
total_sale_platform=data.groupby('Platform').sum()

# %%
top_platform = total_sale_platform.sort_values (by=['Global_Sales'], ascending=False)

# %%
top_platform[:15].Global_Sales.plot(kind='bar', title="Top 15 favorite platforms according to global sales")

# %% [markdown]
# ### Investigating which score correlates with total sell

# %%
import seaborn as sns

# %%
sns.pairplot(data[['User_Score','Critic_Score','ESRB_Rating','Vgchartzscore','Global_Sales','NA_Sales','PAL_Sales','JP_Sales']])
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# #### Although based on this data none of the scores seems to be linearly correlated with sales, however, User_Score, Critics_Score and Vgchartzscore seem to be correlated. This means that in general professional critics agree with users experience

# %% [markdown]
# ### Investigating the most favorite game genre based on critics score

# %%
avg_Critics_score = data.groupby('Genre').mean().Critic_Score.sort_values(ascending=False)

# %%
avg_Critics_score[:10].plot(kind='bar', title="Top 10 game genre based on critics scores", colormap='gray')

# %%
avg_User_score = data.groupby('Genre').mean().User_Score.sort_values(ascending=False)

# %%
avg_User_score[:10].plot(kind='bar', title="Top 10 game genre based on user scores", colormap='gray')

# %% [markdown]
# #### Although user experience and professional critics are slightly different among different genre, there is no significant difference among the different genre in general.
